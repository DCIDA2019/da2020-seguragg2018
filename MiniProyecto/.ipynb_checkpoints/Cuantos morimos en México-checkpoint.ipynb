# %% [markdown]
# # ¿Cuántos morimos en México?

# %% [markdown]
# Para este proyecto se utilizarán datos del INEGI para las muertes en México. Los datos se pueden encontrar en: https://www.inegi.org.mx/temas/mortalidad/. En dicha base de datos se tiene información sobre el volumen de las defunciones registradas en el país, así como algunas características por edad y sexo de los fallecidos y las principales causas que originan los decesos.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
m = pd.read_excel('/Users/guill/Desktop/AC/Bases de datos/mortalidad_00.xlsx')

# %%
m
# Out:
#        cve_entidad              desc_entidad  cve_municipio  \
# 0                0  Estados Unidos Mexicanos              0
# 1                0  Estados Unidos Mexicanos              0
# 2                0  Estados Unidos Mexicanos              0
# 3                0  Estados Unidos Mexicanos              0
# 4                0  Estados Unidos Mexicanos              0
# ...            ...                       ...            ...
# 22835           99           No especificada              0
# 22836           99           No especificada              0
# 22837           99           No especificada              0
# 22838           99           No especificada              0
# 22839           99           No especificada              0
#
#                  desc_municipio  id_indicador  \
# 0      Estados Unidos Mexicanos    1002000030
# 1      Estados Unidos Mexicanos    1002000031
# 2      Estados Unidos Mexicanos    1002000032
# 3      Estados Unidos Mexicanos    1002000033
# ...

# %% [markdown]
# Cuando nos ponemos a indagar en la base de datos nos damos cuenta que primero tiene información general de toda la república, y después tiene datos para cada estado y municipios respectivos, aunque si somos mas minuciosos, cada estado tiene información general de 12 indicadores:
# 1. Defunciones generales
# 2. Defunciones generales hombres
# 3. Defunciones generales mujeres
# 4. Defunciones generales sexo no especificado
# 5. Defunciones de menores de un año
# 6. Defunciones de menores de un año hombres
# 7. Defunciones de menores de un año mujeres
# 8. Defunciones de menores de un año sexo no especificado
# 9. Suicidios registrados
# 10. Índice de sobremortalidad masculina
# 11. Porcentaje de muertes por suicidio con respecto al total de muertes violentas
# 12. Porcentaje de hijos fallecidos de las mujeres de 15 a 49 años
#
# Los datos generales para la república mexicana tienen muchos mas indicadores, entre los cuales podemos destacar además de los anteriores, los siguientes:
# 1. Defunciones por homicidio. Hombre
# 2. Defunciones por homicidio. Mujer
# 3. Tasa de defunciones por homicidio por cada 100 mil habitantes, mujeres
# 4. Tasa de defunciones por homicidio por cada 100 mil habitantes, hombres
# 5. Defunciones por homicidio
# 6. Tasa de defunciones por homicidio por cada 100 mil habitantes

# %% [markdown]
# ## Preguntas

# %% [markdown]
# Podemos hacer preguntas que refieran primeramente a los datos generales de México en los cuales tenemos indicadores bastante interesantes. Posteriormente podemos tratar temas que refieran a cada uno de los estados. Finalmente es evidente que podemos relacionar la base de mortalidad en México, con la base de datos que ya se trató en el curso de homicidios a nivel mundial.
#
# Las preguntas nacionales:
# 1. ¿Cómo ha sido la evolución temporal que la gente que muere en México?
# 2. ¿Cómo ha sido la evolución y distribución de los homicidios en México?
# 3. ¿Cómo ha ido evolucionando el número de suicidios?
# 4. ¿Cómo ha sido la evolución temporal de los menores de un año que mueren en México?
# 5. ¿Cúal es la causa de muerte más común en los últimos años?
#
# Las preguntas estatales:
# 6. ¿Cúales son los estados con mas muertes en los últimos años?
# 7. ¿Cuáles son los estados con mayor número de suicidios en los últimos años?
#
# Las preguntas internacionales:
# 8. ¿Como es la cantidad de homicidios en México si se compara con el resto del mundo?
# 9. ¿Cómo es la cantidad de homicidios en México si se compara con América?

# %% [markdown]
# ### Nacionales

# %% [markdown]
# $\textbf{¿Cómo ha sido la evolución temporal de la gente que muere en México?}$

# %%
defg = m.iloc[0,:]
defg = defg.drop(['cve_entidad', 'desc_entidad', 'cve_municipio', 'desc_municipio', 'id_indicador', 'indicador', 'unidad_medida'], axis=0)
defgh = m.iloc[1,:]
defgh = defgh.drop(['cve_entidad', 'desc_entidad', 'cve_municipio', 'desc_municipio', 'id_indicador', 'indicador', 'unidad_medida'], axis=0)
defgm = m.iloc[2,:]
defgm = defgm.drop(['cve_entidad', 'desc_entidad', 'cve_municipio', 'desc_municipio', 'id_indicador', 'indicador', 'unidad_medida'], axis=0)
defgs = m.iloc[3,:]
defgs = defgs.drop(['cve_entidad', 'desc_entidad', 'cve_municipio', 'desc_municipio', 'id_indicador', 'indicador', 'unidad_medida'], axis=0)

# %%
fig, ax = plt.subplots(figsize=(8, 5), constrained_layout=True)

plt.plot(defg, label ='Generales', color='black')
plt.plot(defgh, label ='Hombres', color='red')
plt.plot(defgm, label = 'Mujeres', color='green')
plt.plot(defgs, label = 'Sexo no especificado', color='blue')

plt.xlabel('Año')
plt.ylabel('Número de muertos')
plt.title('Defunciones generales en México')
plt.setp(ax.get_xticklabels(), rotation=90, ha="right")
plt.legend()
plt.grid()

plt.savefig('dgm.jpg')
plt.show()

# %% [markdown]
# $\textbf{¿Cómo ha sido la evolución y distribución de los homicidios en México?}$

# %%
hom = m.iloc[17,:]
hom = hom.drop(['cve_entidad', 'desc_entidad', 'cve_municipio', 'desc_municipio', 'id_indicador', 'indicador', 'unidad_medida'], axis=0)
hoh = m.iloc[13,:]
hoh = hoh.drop(['cve_entidad', 'desc_entidad', 'cve_municipio', 'desc_municipio', 'id_indicador', 'indicador', 'unidad_medida'], axis=0)
ho = m.iloc[15,:]
ho = ho.drop(['cve_entidad', 'desc_entidad', 'cve_municipio', 'desc_municipio', 'id_indicador', 'indicador', 'unidad_medida'], axis=0)

# %%
fig, ax = plt.subplots(figsize=(8, 5), constrained_layout=True)

plt.plot(hom, label ='Mujeres', color='green')
plt.plot(hoh, label ='Hombres', color='red')
plt.plot(ho, label='General', color='black')


plt.xlabel('Año')
plt.ylabel('Número de muertos')
plt.title('Homicidios totales en México')
plt.setp(ax.get_xticklabels(), rotation=90, ha="right")
plt.legend()
plt.grid()

plt.savefig('homex.jpg')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 5), constrained_layout=True)

plt.plot(hom, color='red')

plt.xlabel('Año')
plt.ylabel('Número de muertos')
plt.title('Homicidios hacia mujeres en México')
plt.setp(ax.get_xticklabels(), rotation=90, ha="right")
plt.grid()

plt.savefig('hom.jpg')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 5), constrained_layout=True)

plt.plot(hoh, color='green')

plt.xlabel('Año')
plt.ylabel('Número de muertos')
plt.title('Homicidios hacia hombres en México')
plt.setp(ax.get_xticklabels(), rotation=90, ha="right")
plt.grid()

plt.savefig('hoh.jpg')
plt.show()

# %%
rhom = m.iloc[14,:]
rhom = rhom.drop(['cve_entidad', 'desc_entidad', 'cve_municipio', 'desc_municipio', 'id_indicador', 'indicador', 'unidad_medida'], axis=0)
rhoh = m.iloc[16,:]
rhoh = rhoh.drop(['cve_entidad', 'desc_entidad', 'cve_municipio', 'desc_municipio', 'id_indicador', 'indicador', 'unidad_medida'], axis=0)
rho = m.iloc[8,:]
rho = rho.drop(['cve_entidad', 'desc_entidad', 'cve_municipio', 'desc_municipio', 'id_indicador', 'indicador', 'unidad_medida'], axis=0)

# %%
fig, ax = plt.subplots(figsize=(8, 5), constrained_layout=True)

plt.plot(rhom, label ='Mujeres', color='green')
plt.plot(rhoh, label ='Hombres', color='red')
plt.plot(rho, label='General', color='black')

plt.xlabel('Año')
plt.ylabel('Número de muertos')
plt.title('Tasa de defunciones por homicidio por cada 100,000 habitantes en México')
plt.setp(ax.get_xticklabels(), rotation=90, ha="right")
plt.legend()
plt.grid()

plt.savefig('hmex_r.jpg')
plt.show()

# %% [markdown]
# $\textbf{¿Cómo ha ido evolucionando el número de suicidios?}$

# %%
sui = m.iloc[9,:]
sui = sui.drop(['cve_entidad', 'desc_entidad', 'cve_municipio', 'desc_municipio', 'id_indicador', 'indicador', 'unidad_medida'], axis=0)

# %%
fig, ax = plt.subplots(figsize=(8, 5), constrained_layout=True)

plt.plot(sui, color='orange')

plt.xlabel('Año')
plt.ylabel('Número de muertos')
plt.title('Suicidios registrados en México')
plt.setp(ax.get_xticklabels(), rotation=90, ha="right")
plt.grid()

plt.savefig('sui.jpg')
plt.show()

# %% [markdown]
# $\textbf{¿Cómo ha sido la evolución temporal de los menores de un año que mueren en México?}$

# %%
dem = m.iloc[4,:]
dem = dem.drop(['cve_entidad', 'desc_entidad', 'cve_municipio', 'desc_municipio', 'id_indicador', 'indicador', 'unidad_medida'], axis=0)
demh = m.iloc[5,:]
demh = demh.drop(['cve_entidad', 'desc_entidad', 'cve_municipio', 'desc_municipio', 'id_indicador', 'indicador', 'unidad_medida'], axis=0)
demm = m.iloc[6,:]
demm = demm.drop(['cve_entidad', 'desc_entidad', 'cve_municipio', 'desc_municipio', 'id_indicador', 'indicador', 'unidad_medida'], axis=0)

# %%
fig, ax = plt.subplots(figsize=(8, 5), constrained_layout=True)

plt.plot(dem, label ='General', color='green')
plt.plot(demh, label ='Hombres', color='red')
plt.plot(demm, label='Mujeres', color='black')


plt.xlabel('Año')
plt.ylabel('Número de muertos')
plt.title('Defunciones de menores de un año')
plt.setp(ax.get_xticklabels(), rotation=90, ha="right")
plt.legend()
plt.grid()

plt.savefig('defmen.jpg')
plt.show()

# %% [markdown]
# $\textbf{¿Cúal es la causa de muerte más común en los últimos años?}$

# %%
sho = 0
sdg = 0
sdem = 0
ssui = 0
defg = defg.fillna(0)
dem = dem.fillna(0)
sui = sui.fillna(0)
for i in range(29):
    sho = float(ho[i]) + aux
    sdg = float(defg[i]) + sdg
    sdem = float(dem[i]) + sdem
    ssui = float(sui[i]) + ssui

# %%
fig, ax = plt.subplots(figsize=(10, 5), constrained_layout=True)


wedges, texts, autotexts = ax.pie([sdg, sdg, sdem, ssui],  
      autopct='%1.0f%%', explode = (0.05,0.05,0.05,0.05), colors=["#b7e778","#c7f0db","#f9d276","#ff8a5c"],
        labels = ['Defunciones generales', 'Homicidios', 'Defunciones de menores de un año', 'Suicidios registrados']
                                 )

ax.legend(wedges, labels,
          title="Indicador",
          loc="best",
          bbox_to_anchor=(1, 0, 0.5, 1))

ax.set_title("Defunciones en México de 1990 a 2018")
plt.setp(autotexts, size=10, weight="bold")

plt.savefig('indidef.jpg')
plt.show()

# %% [markdown]
# ### Estatales

# %% [markdown]
# $\textbf{¿Cúales son los estados con mas muertes en los últimos años?}$

# %%
dxe= pd.Series([],index=[])
maux = m.drop(['cve_entidad', 'desc_entidad', 'cve_municipio', 'desc_municipio', 'id_indicador', 'indicador', 'unidad_medida'], axis=1)
maux = maux.fillna(0)
for i in range(22840):
    if m.iloc[i,0]>=1 and m.iloc[i,2]==0 and m.iloc[i,5]=='Defunciones generales':
        auxs = 0
        for j in range(28):
            auxs = auxs + float(maux.iloc[i,j])
        dxe[m.iloc[i,1]]=auxs
        
dxe = dxe.drop(['Extranjero', 'No especificada'], axis=0)

dxeh= pd.Series([],index=[])
maux = m.drop(['cve_entidad', 'desc_entidad', 'cve_municipio', 'desc_municipio', 'id_indicador', 'indicador', 'unidad_medida'], axis=1)
maux = maux.fillna(0)
for i in range(22840):
    if m.iloc[i,0]>=1 and m.iloc[i,2]==0 and m.iloc[i,5]=='Defunciones generales hombres':
        auxs = 0
        for j in range(28):
            auxs = auxs + float(maux.iloc[i,j])
        dxeh[m.iloc[i,1]]=auxs
        
dxeh = dxeh.drop(['Extranjero', 'No especificada'], axis=0)

dxem= pd.Series([],index=[])
maux = m.drop(['cve_entidad', 'desc_entidad', 'cve_municipio', 'desc_municipio', 'id_indicador', 'indicador', 'unidad_medida'], axis=1)
maux = maux.fillna(0)
for i in range(22840):
    if m.iloc[i,0]>=1 and m.iloc[i,2]==0 and m.iloc[i,5]=='Defunciones generales mujeres':
        auxs = 0
        for j in range(28):
            auxs = auxs + float(maux.iloc[i,j])
        dxem[m.iloc[i,1]]=auxs
        
dxem = dxem.drop(['Extranjero', 'No especificada'], axis=0)

# %%
ind = np.arange(32)
ancho = .35
fig, ax = plt.subplots(figsize=(12, 6), constrained_layout=True)


plt.bar(dxe.index, dxe.values, width = ancho, label='General', color='#42240c')
plt.bar(ind +ancho, dxeh.values, width = ancho, label='Hombres', color='r')
plt.bar(ind + 2*ancho, dxem.values, width = ancho, label='Mujeres', color='g')

plt.xlabel('Estado')
plt.ylabel('Número de muertos')
plt.title('Número total de defunciones generales de 1997 a 2018 por estado')
plt.setp(ax.get_xticklabels(), rotation=70, ha="right")
plt.legend()
plt.grid()

plt.savefig('dgest.jpg')
plt.show()

# %% [markdown]
# $\textbf{¿Cuáles son los estados con mayor número de suicidios en los últimos años?}$

# %%
sxe= pd.Series([],index=[])
maux = m.drop(['cve_entidad', 'desc_entidad', 'cve_municipio', 'desc_municipio', 'id_indicador', 'indicador', 'unidad_medida'], axis=1)
maux = maux.fillna(0)
for i in range(22840):
    if m.iloc[i,0]>=1 and m.iloc[i,2]==0 and m.iloc[i,5]=='Suicidios registrados':
        auxs = 0
        for j in range(28):
            auxs = auxs + float(maux.iloc[i,j])
        sxe[m.iloc[i,1]]=auxs
        
sxe = sxe.drop(['Extranjero'], axis=0)

# %%
fig, ax = plt.subplots(figsize=(10, 6), constrained_layout=True)

plt.bar(sxe.index, sxe.values, color='#7fa998')

plt.xlabel('Estado')
plt.ylabel('Número de muertos')
plt.title('Número total suicidios registrados de 1997 a 2018 por estado')
plt.setp(ax.get_xticklabels(), rotation=70, ha="right")
plt.grid()

plt.savefig('sui_est.jpg')
plt.show()

# %% [markdown]
# ### Internacionales

# %% [markdown]
# Se utilizará la base datos ''Homicide'' que ya se había usado previamente en el curso.

# %%
h = pd.read_csv('/Users/guill/Desktop/AC/Bases de datos/Homicide.csv')
h
# Out:
#          Country  Region        Subregion             Indicator   1990   1991  \
# 0    Afghanistan    Asia    Southern Asia  Homicide Total Count    NaN    NaN
# 1    Afghanistan    Asia    Southern Asia         Homicide Rate    NaN    NaN
# 2        Albania  Europe  Southern Europe  Homicide Total Count    NaN    NaN
# 3        Albania  Europe  Southern Europe         Homicide Rate    NaN    NaN
# 4        Algeria  Africa  Northern Africa  Homicide Total Count    NaN    NaN
# ..           ...     ...              ...                   ...    ...    ...
# 475        Yemen    Asia     Western Asia         Homicide Rate    NaN    NaN
# 476       Zambia  Africa   Eastern Africa  Homicide Total Count  550.0  684.0
# 477       Zambia  Africa   Eastern Africa         Homicide Rate    6.9    8.3
# 478     Zimbabwe  Africa   Eastern Africa  Homicide Total Count  587.0    NaN
# 479     Zimbabwe  Africa   Eastern Africa         Homicide Rate    5.8    NaN
#
# ...

# %% [markdown]
# $\textbf{¿Como es la cantidad de homicidios en México si se compara con el resto del mundo?}$

# %%
europa_total = np.zeros(1)
asia_total = np.zeros(1)
af_total = np.zeros(1)
am_total = np.zeros(1)
oc_total = np.zeros(1)
h = h.fillna(0)
for i in range(479):
    if h.iloc[i,1] == 'Europe' and h.iloc[i,3] == 'Homicide Total Count':
        if europa_total[0] == 0:
            europa_total = h.iloc[i,:]
        else:
            europa_total =  h.iloc[i,:] + europa_total
    
    if h.iloc[i,1] == 'Asia' and h.iloc[i,3] == 'Homicide Total Count':
        if asia_total[0] == 0:
            asia_total = h.iloc[i,:]
        else:
            asia_total =  h.iloc[i,:] + asia_total
    
    if h.iloc[i,1] == 'Africa' and h.iloc[i,3] == 'Homicide Total Count':
        if af_total[0] == 0:
            af_total = h.iloc[i,:]
        else:
            af_total =  h.iloc[i,:] + af_total
    
    if h.iloc[i,1] == 'Americas' and h.iloc[i,3] == 'Homicide Total Count':
        if am_total[0] == 0:
            am_total = h.iloc[i,:]
        else:
            am_total =  h.iloc[i,:] + am_total

    if h.iloc[i,1] == 'Oceania' and h.iloc[i,3] == 'Homicide Total Count':
        if oc_total[0] == 0:
            oc_total = h.iloc[i,:]
        else:
            oc_total =  h.iloc[i,:] + oc_total

europa_total = europa_total.drop(['Country', 'Region', 'Subregion', 'Indicator'], axis=0)
asia_total = asia_total.drop(['Country', 'Region', 'Subregion', 'Indicator'], axis=0)
af_total = af_total.drop(['Country', 'Region', 'Subregion', 'Indicator'], axis=0)
am_total = am_total.drop(['Country', 'Region', 'Subregion', 'Indicator'], axis=0)
oc_total = oc_total.drop(['Country', 'Region', 'Subregion', 'Indicator'], axis=0)

europa_r = np.zeros(1)
asia_r = np.zeros(1)
af_r = np.zeros(1)
am_r = np.zeros(1)
oc_r = np.zeros(1)

auxe = 0
auxas = 0
auxaf = 0
auxam = 0
auxo = 0

for i in range(479):
    if h.iloc[i,1] == 'Europe' and h.iloc[i,3] == 'Homicide Rate':
        if europa_r[0] == 0:
            europa_r = h.iloc[i,:]
        else:
            europa_r =  h.iloc[i,:] + europa_r
            auxe = auxe + 1
    
    if h.iloc[i,1] == 'Asia' and h.iloc[i,3] == 'Homicide Rate':
        if asia_r[0] == 0:
            asia_r = h.iloc[i,:]
        else:
            asia_r =  h.iloc[i,:] + asia_r
            auxas = auxas + 1
    
    if h.iloc[i,1] == 'Africa' and h.iloc[i,3] == 'Homicide Rate':
        if af_r[0] == 0:
            af_r = h.iloc[i,:]
        else:
            af_r =  h.iloc[i,:] + af_r
            auxaf = auxaf + 1
    
    if h.iloc[i,1] == 'Americas' and h.iloc[i,3] == 'Homicide Rate':
        if am_r[0] == 0:
            am_r = h.iloc[i,:]
        else:
            am_r =  h.iloc[i,:] + am_r
            auxam = auxam + 1

    if h.iloc[i,1] == 'Oceania' and h.iloc[i,3] == 'Homicide Rate':
        if oc_r[0] == 0:
            oc_r = h.iloc[i,:]
        else:
            oc_r =  h.iloc[i,:] + oc_r
            auxo = auxo + 1

europa_r = europa_r.drop(['Country', 'Region', 'Subregion', 'Indicator'], axis=0)
asia_r = asia_r.drop(['Country', 'Region', 'Subregion', 'Indicator'], axis=0)
af_r = af_r.drop(['Country', 'Region', 'Subregion', 'Indicator'], axis=0)
am_r = am_r.drop(['Country', 'Region', 'Subregion', 'Indicator'], axis=0)
oc_r = oc_r.drop(['Country', 'Region', 'Subregion', 'Indicator'], axis=0)

europa_r = europa_r/auxe
asia_r = asia_r/auxas
af_r = af_r/auxaf
am_r = am_r/auxam
oc_r = oc_r/auxo

# %%
fig, ax = plt.subplots(figsize=(8, 5), constrained_layout=True)

plt.plot(europa_total, label='Europa')
plt.plot(asia_total, label='Asia')
plt.plot(af_total, label='Africa')
plt.plot(am_total, label = 'América')
plt.plot(oc_total, label = 'Oceania')
plt.plot(ho, label='México', color='black')

plt.xlabel('Año')
plt.ylabel('Número de muertos')
plt.title('Homicidios totales por región')
plt.setp(ax.get_xticklabels(), rotation=90, ha="right")
plt.legend()
plt.grid()

plt.savefig('hom_twm.jpg')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 5), constrained_layout=True)

plt.plot(europa_r, label='Europa')
plt.plot(asia_r, label='Asia')
plt.plot(af_r, label='Africa')
plt.plot(am_r, label = 'América')
plt.plot(oc_r, label = 'Oceania')
plt.plot(rho, label='Mexico', color='black')

plt.xlabel('Año')
plt.ylabel('Número de muertos')
plt.title('Número de homicidios por cada 100,000 habitantes')
plt.setp(ax.get_xticklabels(), rotation=90, ha="right")
plt.legend()
plt.grid()
plt.savefig('hom_rwm.jpg')

plt.show()

# %% [markdown]
# $\textbf{¿Cómo es la cantidad de homicidios en México si se compara con América?}$

# %%
car_total = np.zeros(1)
sa_total = np.zeros(1)
ca_total = np.zeros(1)
na_total = np.zeros(1)

h = h.fillna(0)
for i in range(479):
    if h.iloc[i,2] == 'Caribbean' and h.iloc[i,3] == 'Homicide Total Count':
        if car_total[0] == 0:
            car_total = h.iloc[i,:]
        else:
            car_total =  h.iloc[i,:] + car_total
    
    if h.iloc[i,2] == 'South America' and h.iloc[i,3] == 'Homicide Total Count':
        if sa_total[0] == 0:
            sa_total = h.iloc[i,:]
        else:
            sa_total =  h.iloc[i,:] + sa_total
    
    if h.iloc[i,2] == 'Central America' and h.iloc[i,3] == 'Homicide Total Count':
        if ca_total[0] == 0:
            ca_total = h.iloc[i,:]
        else:
            ca_total =  h.iloc[i,:] + ca_total
    
    if h.iloc[i,2] == 'Northern America' and h.iloc[i,3] == 'Homicide Total Count':
        if na_total[0] == 0:
            na_total = h.iloc[i,:]
        else:
            na_total =  h.iloc[i,:] + na_total


car_total = car_total.drop(['Country', 'Region', 'Subregion', 'Indicator'], axis=0)
sa_total = sa_total.drop(['Country', 'Region', 'Subregion', 'Indicator'], axis=0)
ca_total = ca_total.drop(['Country', 'Region', 'Subregion', 'Indicator'], axis=0)
na_total = na_total.drop(['Country', 'Region', 'Subregion', 'Indicator'], axis=0)

car_r = np.zeros(1)
sa_r = np.zeros(1)
ca_r = np.zeros(1)
na_r = np.zeros(1)

auxc = 0
auxs = 0
aux = 0
auxn = 0

for i in range(479):
    if h.iloc[i,2] == 'Caribbean' and h.iloc[i,3] == 'Homicide Rate':
        if car_r[0] == 0:
            car_r = h.iloc[i,:]
        else:
            car_r =  h.iloc[i,:] + car_r
            auxc = auxc + 1
    
    if h.iloc[i,2] == 'South America' and h.iloc[i,3] == 'Homicide Rate':
        if sa_r[0] == 0:
            sa_r = h.iloc[i,:]
        else:
            sa_r =  h.iloc[i,:] + sa_r
            auxs = auxs + 1
    
    if h.iloc[i,2] == 'Central America' and h.iloc[i,3] == 'Homicide Rate':
        if ca_r[0] == 0:
            ca_r = h.iloc[i,:]
        else:
            ca_r =  h.iloc[i,:] + ca_r
            aux = aux + 1
    
    if h.iloc[i,2] == 'Northern America' and h.iloc[i,3] == 'Homicide Rate':
        if na_r[0] == 0:
            na_r = h.iloc[i,:]
        else:
            na_r =  h.iloc[i,:] + na_r
            auxn = auxn + 1


car_r = car_r.drop(['Country', 'Region', 'Subregion', 'Indicator'], axis=0)
sa_r = sa_r.drop(['Country', 'Region', 'Subregion', 'Indicator'], axis=0)
ca_r = ca_r.drop(['Country', 'Region', 'Subregion', 'Indicator'], axis=0)
na_r = na_r.drop(['Country', 'Region', 'Subregion', 'Indicator'], axis=0)

car_r = car_r/auxc
sa_r = sa_r/auxs
ca_r = ca_r/aux
na_r = na_r/auxn

# %%
fig, ax = plt.subplots(figsize=(8, 5), constrained_layout=True)

plt.plot(car_total, label='Caribe')
plt.plot(sa_total, label='Sudamérica')
plt.plot(ca_total, label='Centroamérica')
plt.plot(na_total, label = 'Norteamérica')
plt.plot(ho, label='México', color='black')

plt.xlabel('Año')
plt.ylabel('Número de muertos')
plt.title('Homicidios totales en américa')
plt.setp(ax.get_xticklabels(), rotation=90, ha="right")
plt.legend()
plt.grid()

plt.savefig('ha_twm.jpg')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 5), constrained_layout=True)

plt.plot(car_r, label='Caribe')
plt.plot(sa_r, label='Sudamérica')
plt.plot(ca_r, label='Centroamérica')
plt.plot(na_r, label = 'Norteamérica')
plt.plot(rho, label='Mexico', color='black')

plt.xlabel('Año')
plt.ylabel('Número de muertos')
plt.title('Homicidios por cada 100,000 habitantes en América')
plt.setp(ax.get_xticklabels(), rotation=90, ha="right")
plt.legend()
plt.grid()

plt.savefig('ha_rwm.jpg')
plt.show()
